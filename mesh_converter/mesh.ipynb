# %%
import meshio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import meshio
#
# ModuleNotFoundError: No module named 'meshio'

# %%
conda install -c conda-forge meshio
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/dbey/miniconda3/envs/jax
#
#   added / updated specs:
#     - meshio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     c-ares-1.34.2              |       heb4867d_0         201 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     cftime-1.6.2               |  py312ha883a20_1         233 KB
#     h5py-3.11.0                |  py312h34c39bb_0         1.4 MB
#     hdf4-4.2.13                |    h10796ff_1005         949 KB  conda-forge
#     hdf5-1.12.1                |       h2b7332f_3         5.4 MB
#     libcurl-8.9.1              |       h251f7ec_0         439 KB
# ...
